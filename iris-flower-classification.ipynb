# %%
# Importing Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.groupby('species').mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# # Data Visualization

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.show()

# %%
sns.lineplot(data=iris.drop(['species'], axis=1))
plt.show()

# %%
iris.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
plt.show()

# %%
sns.heatmap(iris.corr(), annot=True)
plt.show()

# %%
g = sns.FacetGrid(iris, col='species')
g = g.map(sns.kdeplot, 'sepal_length')

# %%
sns.pairplot(iris)

# %%
iris.hist(color= 'mediumpurple' ,edgecolor='black',figsize=(10,10))
plt.show()

# %%
iris.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_a3185_row0_col0, #T_a3185_row1_col1, #T_a3185_row2_col2, #T_a3185_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3185_row0_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_a3185_row0_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_a3185_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_a3185_row1_col0, #T_a3185_row1_col2, #T_a3185_row1_col3, #T_a3185_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a3185_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a3185_row2_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_a3185_row3_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_a3185_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_a3185_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3185_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sepal_length</th>
#       <th class="col_heading level0 col1" >sepal_width</th>
#       <th class="col_heading level0 col2" >petal_length</th>
#       <th class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3185_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_a3185_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a3185_row0_col1" class="data row0 col1" >-0.11</td>
#       <td id="T_a3185_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_a3185_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_a3185_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_a3185_row1_col0" class="data row1 col0" >-0.11</td>
#       <td id="T_a3185_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a3185_row1_col2" class="data row1 col2" >-0.42</td>
#       <td id="T_a3185_row1_col3" class="data row1 col3" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_a3185_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_a3185_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_a3185_row2_col1" class="data row2 col1" >-0.42</td>
#       <td id="T_a3185_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a3185_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_a3185_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_a3185_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_a3185_row3_col1" class="data row3 col1" >-0.36</td>
#       <td id="T_a3185_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_a3185_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
x = iris.drop('species', axis=1)
y= iris.species

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=5)

# %% [markdown]
# K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(x_train, y_train)

knn.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x, y)
y_pred = logreg.predict(x)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.9733333333333334

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
svm.fit(x_train, y_train)

svm.score(x_test, y_test)
# Out:
# 0.9833333333333333

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)

dtree.score(x_test, y_test)
# Out:
# 0.95
